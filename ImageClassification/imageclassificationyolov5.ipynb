# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/classify/train.py --model yolov5s-cls.pt --data /home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data --epochs 100 --img 224
# Out:
# classify/train: model=yolov5s-cls.pt, data=/home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data, epochs=100, batch_size=64, imgsz=224, nosave=False, cache=None, device=, workers=8, project=yolov5/runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train-cls', view at http://localhost:6006/
# 2023-03-28 15:19:56.643108: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/classify/val.py --data /home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train-cls/exp8/weights/best.pt --img 224
# Out:
# classify/val: data=/home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data, weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train-cls/exp8/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=yolov5/runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4197432 parameters, 0 gradients, 10.4 GFLOPs
# testing: 100%|██████████| 25/25 [00:02<00:00,  8.43it/s]
#                    Class      Images    top1_acc    top5_acc
#                      all        3110           1           1
#                  apple_6         157           1           1
#         apple_braeburn_1         160           1           1
#     apple_crimson_snow_1         159           1           1
#           apple_golden_1         154           1           1
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/classify/predict.py --data /home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train-cls/exp8/weights/best.pt --img 224
# Out:
# classify/predict: weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train-cls/exp8/weights/best.pt'], source=yolov5/data/images, data=/home/harish/M_Lens/Deepthi/deepthi_data/image_classification/data, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=yolov5/runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4197432 parameters, 0 gradients, 10.4 GFLOPs
# image 1/2 /home/harish/M_Lens/Deepthi/yolov5/data/images/bus.jpg: 224x224 eggplant_violet_1 0.21, apple_hit_1 0.09, zucchini_dark_1 0.08, cucumber_1 0.07, pear_1 0.05, 3.3ms
# image 2/2 /home/harish/M_Lens/Deepthi/yolov5/data/images/zidane.jpg: 224x224 eggplant_violet_1 0.18, cucumber_1 0.10, zucchini_dark_1 0.10, apple_braeburn_1 0.08, apple_red_3 0.07, 3.3ms
# ...

# %%
# %pip install -r /home/harish/M_Lens/Deepthi/yolov5/requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/train.py --img 640 --batch 16 --epochs 300 --data /home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml --weights yolov5n.pt --device 0
# Out:
# train: weights=yolov5n.pt, cfg=, data=/home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/val.py --img 640 --batch 16 --data /home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt--device 0
# Out:
# val: data=/home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml, weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# val: Scanning /home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/label
#                  Class     Images  Instances          P          R      mAP50
#                    all         75         81      0.903      0.806       0.91      0.637
#               negative         75         81      0.903      0.806       0.91      0.637
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/detect.py --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt --source /home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg
# Out:
# detect: weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt'], source=/home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# image 1/1 /home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg: 640x640 2 negatives, 6.4ms
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/export.py --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt --include tflite --img 416
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp5/weights/best.pt with output shape (1, 10647, 7) (3.7 MB)
# 2023-03-28 15:40:56.904140: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

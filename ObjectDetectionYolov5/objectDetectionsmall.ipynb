# %%
# %pip install -r /home/harish/M_Lens/Deepthi/yolov5/requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# ...
#      |████████████████████████████████| 3.3 MB 2.4 MB/s eta 0:00:01
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#      |████████████████████████████████| 77 kB 11.2 MB/s  eta 0:00:01
# ...
#   Using cached tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
# ...
#      |████████████████████████████████| 1.1 MB 125.6 MB/s eta 0:00:01
# ...
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# ...
#      |████████████████████████████████| 93 kB 4.8 MB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 302 kB 124.7 MB/s eta 0:00:01
# ...
#   Using cached tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#      |████████████████████████████████| 5.0 MB 110.0 MB/s eta 0:00:01
# ...
#   Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/train.py --img 640 --batch 16 --epochs 300 --data /home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml --weights yolov5s.pt --device 0
# Out:
# train: weights=yolov5s.pt, cfg=, data=/home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/val.py --img 640 --batch 16 --data /home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt --device 0
# Out:
# val: data=/home/harish/M_Lens/Deepthi/yolov5/data/custom_data.yaml, weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /home/harish/M_Lens/Deepthi/data/axial_t1wce_2_class/labels/test.c
#                  Class     Images  Instances          P          R      mAP50
#                    all         75         81      0.921      0.862      0.931      0.667
#               negative         75         81      0.921      0.862      0.931      0.667
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/detect.py --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt --source /home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg
# Out:
# detect: weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt'], source=/home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/harish/M_Lens/Deepthi/deepthi_data/axial_t1wce_2_class/images/test/00018_101.jpg: 640x640 2 negatives, 6.1ms
# ...

# %%
# !python3 /home/harish/M_Lens/Deepthi/yolov5/export.py --weights /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt --include tflite --img 416
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /home/harish/M_Lens/Deepthi/yolov5/runs/train/exp2/weights/best.pt with output shape (1, 10647, 7) (13.8 MB)
# 2023-03-28 15:41:03.707780: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %pip install -r /home/harish/M_Lens/Deepthi/yolov5/requirements.txt coremltools onnx onnx-simplifier onnxruntime-gpu openvino-dev tensorflow  # GPU
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 4.7 MB/s eta 0:00:01
# ...
#   Using cached onnx-1.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# ...
#      |████████████████████████████████| 2.1 MB 13.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 136.2 MB 130 kB/s  eta 0:00:01    |██████████▋                     | 45.3 MB 64.6 MB/s eta 0:00:02     |███████████▉                    | 50.3 MB 64.6 MB/s eta 0:00:02     |██████████████▊                 | 62.7 MB 36.7 MB/s eta 0:00:02     |███████████████▎                | 65.2 MB 36.7 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 5.8 MB 30.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 585.9 MB 7.2 kB/s  eta 0:00:01
# ...
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# ...
#   Using cached protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#      |████████████████████████████████| 238 kB 25.5 MB/s eta 0:00:01
# ...
